# %%
'''
Abstract: Predict the age of abalone from physical measurements

Data Set Information:
http://archive.ics.uci.edu/ml/datasets/Abalone

Define the problem
Prepare data
Evaluate algorithms
Improve results
Write-up results

'''

# 1 DEFINE THE PROBLEM
## Find most accurate algorithm to use on above dataset, save model for later use

# 1.1 LOAD LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
## Will load other libraries on the go
from pandas.plotting import scatter_matrix 

# 1.2 LOAD DATASET
url = 'https://raw.githubusercontent.com/Savinda/datasets/master/pyTutes/datasets/abalone.csv'
names = ['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings']
ab_dataset = pd.read_csv(url, names=names)

# %%
# 2 SUMMERIZE DATA
# 2.1 Descriptive Statistics
ab_dataset.head()
print(ab_dataset.shape)
print(ab_dataset.dtypes)
print(ab_dataset.describe())
print(ab_dataset.corr())

# 2.2 Data visualization
ab_dataset.hist()
ab_dataset.plot(kind='box')
plt.show()
scatter_matrix(ab_dataset, figsize=(8.0,8.0))
plt.show()
# Out:
# (4177, 9)
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
# ...

# %%
# 3 PREPARE DATA
# 3.1 Data cleaning
# 3.1.1 Split in to train and test sets
array = ab_dataset.values
# use sklearn.feature_extraction.DictVectorizer for Male or Female Indexing
for label in 'MFI':
    ab_dataset[label] = ab_dataset['Sex'] == label
del ab_dataset['Sex']
ab_dataset.head()

rings = ab_dataset['Rings'].values
# seperate array into input and output components
y = ab_dataset.rings.values

del ab_dataset['Rings'] # Remove 'Rings from data, so we can convert all the dataframe into numpy 2D array'
X = ab_dataset.values.astype(np.float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-62b0898e7bd0> in <module>
#      11 rings = ab_dataset['Rings'].values
#      12 # seperate array into input and output components
# ---> 13 y = ab_dataset.rings.values
#      14
#      15 del ab_dataset['Rings'] # Remove 'Rings from data, so we can convert all the dataframe into numpy 2D array'
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rings'
